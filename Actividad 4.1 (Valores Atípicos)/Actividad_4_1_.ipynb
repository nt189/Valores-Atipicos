# %% [markdown]
# <a href="https://colab.research.google.com/github/nt189/Valores-Atipicos/blob/main/Actividad%204.1%20(Valores%20At%C3%ADpicos)/Actividad_4_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Carga del dataframe
df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')

# %%
# Verificacion de nulos
df.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   bool
#  1   FECHA_DOC                  1426 non-null   bool
#  2   NOMBRE_VENDEDOR            1426 non-null   bool
#  3   NOMBRE_CLIENTE             1426 non-null   bool
#  4   CANT                       1426 non-null   bool
#  5   CVE_ART                    1426 non-null   bool
#  6   DESCR                      1426 non-null   bool
#  7   PRECIO_UNITARIO            1426 non-null   bool
#  8   COSTO_UNITARIO             1426 non-null   bool
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   bool
#  10  SUBTOTAL_PARTIDA           1426 non-null   bool
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   bool
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   bool
#  13  MARGEN_TOTAL_CALCULADO     1426 non-null   bool
# dtypes: bool(14)
# memory usage: 19.6 KB

# %%
# Verificacion de nulos
df.isnull().sum()
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              2
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
# Eliminamos filas con nulos
df = df.dropna()

# %%
# Verificacion de nulos
df.isnull().sum()
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %% [markdown]
# # **Inicio de tratamiento para valores atipicos**

# %%
# Creo 2 dataframe para poder procesar los outliers
cuantitativas = df.iloc[:, [4,7,8,9,10,11,12,13]]
cualitativas = df.iloc[:, [0,1,2,3,5,6]]

# %%
cuantitativas
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0        1           434.48           52.80                     52.80
# 1        1          1264.05          327.18                    327.18
# 2        7           551.61          177.68                    177.68
# 3        1           140.00           38.96                     38.96
# 4        2           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421     6           712.00          102.31                    102.31
# 1422     6           718.60          104.69                    104.69
# 1423     3          2182.35            0.00                    596.55
# 1424     1          5909.84         1884.35                   1884.35
# 1425    10          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 0               434.48                  52.80                     381.68
# 1              1264.05                 327.18                     936.87
# 2              3861.29                1243.73                     373.94
# 3               140.00                  38.96                     101.04
# 4               344.83                 203.42                      70.71
# ...                ...                    ...                        ...
# 1421           4272.00                 613.88                     609.69
# 1422           4311.60                 628.12                     613.91
# 1423           6547.05                1789.64                    1585.80
# 1424           5909.84                1884.35                    4025.49
# 1425          14060.00                 806.55                    1325.34
#
#       MARGEN_TOTAL_CALCULADO
# 0                     381.68
# 1                     936.87
# 2                    2617.56
# 3                     101.04
# 4                     141.41
# ...                      ...
# 1421                 3658.12
# 1422                 3683.48
# 1423                 4757.41
# 1424                 4025.49
# 1425                13253.45
#
# [1424 rows x 8 columns]

# %% [markdown]
# # **Diagramas de caja o bigote**

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de cada columna del dataframe/Valores Atipicos del DataFrame')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['CANT'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna CANT')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['PRECIO_UNITARIO'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna PRECIO_UNITARIO')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['COSTO_UNITARIO'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna COSTO_UNITARIO')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['COSTO_UNITARIO_CALCULADO'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna COSTO_UNITARIO_CALCULADO')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['SUBTOTAL_PARTIDA'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna SUBTOTAL_PARTIDA')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['COSTO_TOTAL_CALCULADO'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna COSTO_TOTAL_CALCULADO')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['MARGEN_UNITARIO_CALCULADO'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna MARGEN_UNITARIO_CALCULADO')
plt.show()

# %%
# Realizamos diagramas de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas['MARGEN_TOTAL_CALCULADO'].plot(kind='box', vert=False)
plt.title('Diagramas de caja o bigote de la columna MARGEN_TOTAL_CALCULADO')
plt.show()

# %% [markdown]
# # **Rango interculatico**

# %%
# Metodo aplicando cuantiles. Encuentro cuartiles 0.25 y 0.75
y = cuantitativas

percentiles25  = y.quantile(0.25)
percentiles75 = y.quantile(0.75)
iqr = percentiles75 - percentiles25

Limite_Superior_iqr = percentiles75 + 1.5*iqr
Limite_Inferior_iqr = percentiles25 - 1.5*iqr

print("Limite superior permitido")
print(Limite_Superior_iqr)
print("Limite inferior permitido")
print(Limite_Inferior_iqr)
# Out:
# Limite superior permitido
# CANT                             8.50000
# PRECIO_UNITARIO               2955.57375
# COSTO_UNITARIO                 567.95000
# COSTO_UNITARIO_CALCULADO       808.48375
# SUBTOTAL_PARTIDA             10780.00500
# COSTO_TOTAL_CALCULADO         2975.35000
# MARGEN_UNITARIO_CALCULADO     2095.53375
# MARGEN_TOTAL_CALCULADO        7815.92375
# dtype: float64
# Limite inferior permitido
# CANT                           -3.50000
# PRECIO_UNITARIO              -927.35625
# COSTO_UNITARIO               -340.77000
# COSTO_UNITARIO_CALCULADO     -341.36625
# SUBTOTAL_PARTIDA            -4932.27500
# COSTO_TOTAL_CALCULADO       -1508.49000
# MARGEN_UNITARIO_CALCULADO    -624.49625
# MARGEN_TOTAL_CALCULADO      -3592.20625
# dtype: float64

# %%
# Obtenemos datos limpios del DataFrame
Datos_sin_Outliers_iqr = cuantitativas[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
Datos_sin_Outliers_iqr
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0              NaN             NaN                       NaN
# 1425   NaN          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 0               434.48                  52.80                     381.68
# 1              1264.05                 327.18                     936.87
# 2              3861.29                1243.73                     373.94
# 3               140.00                  38.96                     101.04
# 4               344.83                 203.42                      70.71
# ...                ...                    ...                        ...
# 1421           4272.00                 613.88                     609.69
# 1422           4311.60                 628.12                     613.91
# 1423           6547.05                1789.64                    1585.80
# 1424           5909.84                1884.35                        NaN
# 1425               NaN                 806.55                    1325.34
#
#       MARGEN_TOTAL_CALCULADO
# 0                     381.68
# 1                     936.87
# 2                    2617.56
# 3                     101.04
# 4                     141.41
# ...                      ...
# 1421                 3658.12
# 1422                 3683.48
# 1423                 4757.41
# 1424                 4025.49
# 1425                     NaN
#
# [1424 rows x 8 columns]

# %%
# contar nulos por columnas
Datos_sin_Outliers_iqr.isnull().sum()
# Out:
# CANT                         169
# PRECIO_UNITARIO              127
# COSTO_UNITARIO               128
# COSTO_UNITARIO_CALCULADO     144
# SUBTOTAL_PARTIDA             159
# COSTO_TOTAL_CALCULADO        162
# MARGEN_UNITARIO_CALCULADO    131
# MARGEN_TOTAL_CALCULADO       168
# dtype: int64

# %%
# Remplazamos valores atipicos del dataframe con mean
df_clean_iqr = Datos_sin_Outliers_iqr.copy()
df_clean_iqr = df_clean_iqr.fillna(round(Datos_sin_Outliers_iqr.mean(),1))
df_clean_iqr
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0           943.30          108.00                    220.00
# 1425   2.4          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 0               434.48                  52.80                     381.68
# 1              1264.05                 327.18                     936.87
# 2              3861.29                1243.73                     373.94
# 3               140.00                  38.96                     101.04
# 4               344.83                 203.42                      70.71
# ...                ...                    ...                        ...
# 1421           4272.00                 613.88                     609.69
# 1422           4311.60                 628.12                     613.91
# 1423           6547.05                1789.64                    1585.80
# 1424           5909.84                1884.35                     686.30
# 1425           2579.80                 806.55                    1325.34
#
#       MARGEN_TOTAL_CALCULADO
# 0                     381.68
# 1                     936.87
# 2                    2617.56
# 3                     101.04
# 4                     141.41
# ...                      ...
# 1421                 3658.12
# 1422                 3683.48
# 1423                 4757.41
# 1424                 4025.49
# 1425                 1848.60
#
# [1424 rows x 8 columns]

# %%
# contar nulos por columnas
df_clean_iqr.isnull().sum()
# Out:
# CANT                         0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %% [markdown]
# # **Desviacion estandar**

# %%
# Metodo aplicando desviacion estandar, Encuentro los valores extremos
y = cuantitativas
Limite_Superior = y.mean() + 3*y.std()
Limite_Inferior = y.mean() - 3*y.std()
print("Limite superiror para desviacion estandar: ")
print(Limite_Superior)
print("Limite inferior para desviacion estandar: ")
print(Limite_Inferior)
# Out:
# Limite superiror para desviacion estandar:
# CANT                            22.545789
# PRECIO_UNITARIO               9540.206932
# COSTO_UNITARIO                3315.756325
# COSTO_UNITARIO_CALCULADO     16698.597401
# SUBTOTAL_PARTIDA             31422.747683
# COSTO_TOTAL_CALCULADO        18642.648054
# MARGEN_UNITARIO_CALCULADO    16012.576133
# MARGEN_TOTAL_CALCULADO       28710.917165
# dtype: float64
# Limite inferior para desviacion estandar:
# CANT                           -14.329497
# PRECIO_UNITARIO              -6502.871258
# COSTO_UNITARIO               -2823.515215
# COSTO_UNITARIO_CALCULADO    -15614.533567
# SUBTOTAL_PARTIDA            -21412.631868
# COSTO_TOTAL_CALCULADO       -15813.119782
# MARGEN_UNITARIO_CALCULADO   -14059.304181
# MARGEN_TOTAL_CALCULADO      -21530.329398
# dtype: float64

# %%
# Obtenemos datos y los outliers se convierten en nulos en el DataFrame
Datos_sin_Outliers = cuantitativas[(y <= Limite_Superior) & (y >= Limite_Inferior)]
Datos_sin_Outliers
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0          5909.84         1884.35                   1884.35
# 1425  10.0          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 0               434.48                  52.80                     381.68
# 1              1264.05                 327.18                     936.87
# 2              3861.29                1243.73                     373.94
# 3               140.00                  38.96                     101.04
# 4               344.83                 203.42                      70.71
# ...                ...                    ...                        ...
# 1421           4272.00                 613.88                     609.69
# 1422           4311.60                 628.12                     613.91
# 1423           6547.05                1789.64                    1585.80
# 1424           5909.84                1884.35                    4025.49
# 1425          14060.00                 806.55                    1325.34
#
#       MARGEN_TOTAL_CALCULADO
# 0                     381.68
# 1                     936.87
# 2                    2617.56
# 3                     101.04
# 4                     141.41
# ...                      ...
# 1421                 3658.12
# 1422                 3683.48
# 1423                 4757.41
# 1424                 4025.49
# 1425                13253.45
#
# [1424 rows x 8 columns]

# %%
# contar nulos por columnas
Datos_sin_Outliers.isnull().sum()
# Out:
# CANT                         28
# PRECIO_UNITARIO              29
# COSTO_UNITARIO               10
# COSTO_UNITARIO_CALCULADO      2
# SUBTOTAL_PARTIDA             36
# COSTO_TOTAL_CALCULADO         5
# MARGEN_UNITARIO_CALCULADO    13
# MARGEN_TOTAL_CALCULADO       24
# dtype: int64

# %%
# Rellenamos los valores atipicos con la media
df_clean = Datos_sin_Outliers.copy()
df_clean = df_clean.fillna(round(Datos_sin_Outliers.mean(),1))
df_clean
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0          5909.84         1884.35                   1884.35
# 1425  10.0          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# 0               434.48                  52.80                     381.68
# 1              1264.05                 327.18                     936.87
# 2              3861.29                1243.73                     373.94
# 3               140.00                  38.96                     101.04
# 4               344.83                 203.42                      70.71
# ...                ...                    ...                        ...
# 1421           4272.00                 613.88                     609.69
# 1422           4311.60                 628.12                     613.91
# 1423           6547.05                1789.64                    1585.80
# 1424           5909.84                1884.35                    4025.49
# 1425          14060.00                 806.55                    1325.34
#
#       MARGEN_TOTAL_CALCULADO
# 0                     381.68
# 1                     936.87
# 2                    2617.56
# 3                     101.04
# 4                     141.41
# ...                      ...
# 1421                 3658.12
# 1422                 3683.48
# 1423                 4757.41
# 1424                 4025.49
# 1425                13253.45
#
# [1424 rows x 8 columns]

# %%
# contar nulos por columnas
df_clean.isnull().sum() #Metodo de desviacion estandar le cuesta detectar
# Out:
# CANT                         0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64
